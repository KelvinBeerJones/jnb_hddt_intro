# %% [markdown]
# # Introduction to the Historical Data Digital Toolkit (HDDT) #

# %%
# First we call up the python packages we need to perform the analysis:

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(20, 10))
from operator import itemgetter
import networkx as nx
from networkx.algorithms import community #This part of networkx, for community detection, needs to be imported separately.
import nbconvert
import csv

# <img src="xxxx.png">

# %% [markdown]
# ## What is a dataset? ##
#
# A 'Complete' dataset would be one like this, where all of the data can be contained witin a perfect rectangular block of cells ('containers') and every container contains only one data item and every data item can be located by the coordinates 'Row n, Column n'
#
# <img src="data 1.png">
#
# When historical data is used often some data is missing (permanently lost) and a Historical Data Digital Toolkit musy be able to accept 'Incomplete' datasets. The HDDT does not lose functionality because of the incomplete nature of much historical data.
#
# <img src="data 2.png">
#
# The HDDT has been designed to accept Irregular datasets. The surviving evidence of the past is not only often Incomplete, it is Irregular, where datasets frequently have different dimensions. (Either because the data in itself is intrinsically different or because different data collectors use different cataloguing methods)
#
# <img src="data 3.png">
#
# For the HDDT a dataset is a data set of any dimensions, complete or incomplete. The only requirement is that all datasets must contain a single common and universally shared data item. The HDDT requires all data sets to contain datasets that have PERSON (Name) in one of its rows.
#
# Conflicts between dataset Person (Name)'s are resolved by adopting the 'main dataset' as the Authority Index. In this case the main dataset is that kindly provided by RAI and, with careful matching of Person (Name)'s found in other datasets, the RAI naming rule applies throughout.

# %% [markdown]
# # The Entity Relationship Diagram of the HDDT #

# %% [markdown]
# <img src="ERD.png">

# %% [markdown]
# # Data Sources #

# %% [markdown]
# # Data Types #
#
# ## Static bipartite or bigraph data ##
#
# ## Dynamic bigraph data ##
#
# ## Dymanic social network data ##

# %%
with open('vw_3_all_bipartite_names_1_2_202108181938.csv', 'r') as nodecsv: # Open the file
    nodereader = csv.reader(nodecsv) # Read the csv
    nodes = [n for n in nodereader][1:]  # Retrieve the data (using Python list comprhension and list slicing to remove the header row.
    
node_names = [n[0] for n in nodes] # Get a list of only the node names    

with open('vw_2_all_bipartite_memberships_xid_202108181937.csv', 'r') as edgecsv: # Open the file
    edgereader = csv.reader(edgecsv) # Read the csv
    edges = [tuple(e) for e in edgereader][1:]  # Retrieve the data

# %%
nodes
# Out:
# [[' Joseph Storrs'],
#  ['A  Mackintosh Shaw'],
#  ['A  de Fullner'],
#  ['A , jun Ramsay'],
#  ['A A Stewart'],
#  ['A Ambrose'],
#  ['A B Stark'],
#  ['A B Wright'],
#  ['A Bell'],
#  ['A C Brebner'],
#  ['A Crowley'],
#  ['A Dale'],
#  ['A Ellis'],
#  ['A F Forsell'],
#  ['A Fitzjames'],
#  ['A Friend'],
#  ['A G Cross'],
#  ['A H Russell'],
#  ['A Heaviside'],
#  ['A Hodgson'],
#  ['A Ioannides'],
#  ['A J Larking'],
#  ['A J Lorking'],
#  ['A Janson'],
#  ['A L  (pere) Gosse'],
#  ['A L Wigan'],
#  ['A Milne'],
#  ['A P Balkwill'],
#  ['A Reid'],
#  ['A Roberts'],
#  ['A Schumann'],
#  ['A Thistlethwaite'],
#  ['A W Parsons'],
#  ['A Wells'],
#  ['AI'],
#  ['APS'],
#  ['ASL'],
#  ['Abell Smith'],
#  ['Aberdeen Horticultural Society'],
#  ['Abraham Crowley'],
#  ['Abraham Fisher'],
#  ['Abraham Logan'],
#  ['Abraham Sewell'],
#  ['Abram Rawlinson Barclay'],
#  ['Academia Quirurgia of Madrid'],
#  ['Academie Hongroise de Pest'],
#  ['Academy of Anatolia'],
#  ['Academy of Medicine and Surgery of Madrid and Barcelona'],
#  ['Academy of Natural Sciences Philadelphia'],
#  ['Academy of Natural Sciences of Spain'],
#  ['Academy of Surgery, Madrid'],
#  ['Acclimatisation Society'],
#  ['Adam Storey Farrar'],
#  ['Adolf Bastian'],
#  ['Adolf Ernst'],
#  ['Adolph Bendir'],
#  ['Adolphe Duchart Fauvet'],
#  ['Adrian Balbi'],
#  ['Africa'],
#  ['Agnes Craig'],
#  ['Alan Cornwall Blackstone'],
#  ['Albania'],
#  ['Albemarle Burlington Club'],
#  ['Albert Fytche'],
#  ['Albert Gledstanes'],
#  ['Albert Mitchell'],
#  ['Albert Taylor Bledsoe'],
#  ['Albert Tootal'],
#  ['Aldin Grout'],
#  ['Alex  Nidda Genthe'],
#  ['Alexander (1) Mitchell'],
#  ['Alexander Adolphus Fraser'],
#  ['Alexander Aria'],
#  ['Alexander C Hamilton'],
#  ['Alexander Colvin Fraser'],
#  ['Alexander Cunningham'],
#  ['Alexander Downing'],
#  ['Alexander Duncan'],
#  ['Alexander Ecker'],
#  ['Alexander Fiddes'],
#  ['Alexander Grace'],
#  ['Alexander Gregg'],
#  ['Alexander Guthrie'],
#  ['Alexander Hector'],
#  ['Alexander Henderson'],
#  ['Alexander Humboldt, Von'],
#  ['Alexander Isbester'],
#  ['Alexander Macnamee Walker'],
#  ['Alexander McArthur'],
#  ['Alexander Michie'],
#  ['Alexander Milne Dunlop'],
#  ['Alexander Moir'],
#  ['Alexander Morison'],
#  ['Alexander Muirhead Aitken'],
#  ['Alexander Nasmyth'],
#  ['Alexander Norman Tate'],
#  ['Alexander Paspati'],
#  ['Alexander Patrick Stewart'],
#  ['Alexander Robertson'],
#  ['Alexander Robertson (2)'],
#  ['Alexander Walker'],
#  ['Alexis Fedschenko'],
#  ['Alfred Aubert'],
#  ['Alfred Backhouse'],
#  ['Alfred Barton'],
#  ['Alfred Becquet'],
#  ['Alfred Club'],
#  ['Alfred Edmund Harriss'],
#  ['Alfred Gutteres Henriques'],
#  ['Alfred Henry Pechell'],
#  ['Alfred Henry Wilson'],
#  ['Alfred Hewlett'],
#  ['Alfred Higgins'],
#  ['Alfred How'],
#  ['Alfred John Dunkin'],
#  ['Alfred Kitching'],
#  ['Alfred L Fox'],
#  ['Alfred M Sanderson'],
#  ['Alfred Mallalieu'],
#  ['Alfred Maury'],
#  ['Alfred Pulford'],
#  ['Alfred Ransome'],
#  ['Alfred Robert Houghton'],
#  ['Alfred Robert Thompson'],
#  ['Alfred Rosling'],
#  ['Alfred Russel Wallace'],
#  ['Alfred S Rogers'],
#  ['Alfred Sadler'],
#  ['Alfred Sanders'],
#  ['Alfred Smith'],
#  ['Alfred Spencer Churchill'],
#  ['Alfred Tubb Windus'],
#  ['Alfred Vincent Newton'],
#  ['Alfred Wake'],
#  ['Alfred Waterhouse'],
#  ['Alfred Wiltshire'],
#  ['Alfred von Kremer'],
#  ['Algernon Charles Swinburne'],
#  ['Algernon Joy'],
#  ['Algernon Peckover'],
#  ['Algic Society'],
#  ['Alois Auer'],
#  ['Alphonse de Fleuriot de Langle'],
#  ['Alpine Club'],
#  ['America'],
#  ['American Ethnological Society'],
#  ['American Jewish Historical Society'],
#  ['American Medical Association'],
#  ['American Oriental Society'],
#  ['Amos Beardsley'],
#  ['Anastasius Agathides'],
#  ['Anatoly Petrovich Bogdanoff'],
#  ['Anders Retzius'],
#  ['Andrew & Jun Johnston'],
#  ['Andrew Black'],
#  ['Andrew Gilmour'],
#  ['Andrew Johnston'],
#  ['Andrew Lang'],
#  ['Andrew Maclure'],
#  ['Andrew McCallum'],
#  ['Andrew Mercer Adam'],
#  ['Andrew Scott Waugh'],
#  ['Andrew Smith'],
#  ['Andrew Stewart'],
#  ['Andrew Struthers'],
#  ['Andrew Valentine Kirwan'],
#  ['Andrew Wilson'],
#  ['Andrew Wyley'],
#  ['Angelo Manzoni'],
#  ['Ankithum Venkata Nursing Row'],
#  ['Ann Cropper'],
#  ['Ann Crowley'],
#  ['Ann Everett'],
#  ['Ann Gibson'],
#  ['Ann Hopkins Smith'],
#  ['Ann M Hopkins'],
#  ['Ann Snowden'],
#  ['Ann Tweedy'],
#  ['Ann W Christy'],
#  ['Ann Wallis'],
#  ['Anna Gurney'],
#  ['Anthony Dinsdale'],
#  ['Anthony Lax Fisher'],
#  ['Anthony White'],
#  ['Anthropological Institute of New York'],
#  ['Anthropological Society of Berlin'],
#  ['Anthropological Society of Moscow'],
#  ['Anthropological Society of Paris'],
#  ['Anthropological Society of Washington'],
#  ['Anton Fritsch'],
#  ['Antonio Brady'],
#  ['Antonio Garbiglietti'],
#  ['Antonio Raimondi'],
#  ['Antonio de La, jun Cerda'],
#  ['Archibald Campbell'],
#  ['Archibald Hamilton'],
#  ['Archibald Robertson'],
#  ['Argentina'],
#  ['Armenia'],
#  ['Armenius Vambery'],
#  ['Army & Navy Club'],
#  ['Arthur Albright'],
#  ['Arthur B Ewen'],
#  ['Arthur B Harris'],
#  ['Arthur Charles Wriothesley Lennox'],
#  ['Arthur Chilver Tupper'],
#  ['Arthur Constantine Ionides'],
#  ['Arthur Daniel Aulton'],
#  ['Arthur Dashwood'],
#  ['Arthur Edmund Crafter'],
#  ['Arthur Edward Downing'],
#  ['Arthur Edward McCallum'],
#  ['Arthur Giles Puller'],
#  ['Arthur Gordon Gordon'],
#  ['Arthur Hill'],
#  ['Arthur Johnson'],
#  ['Arthur Mitchell'],
#  ['Arthur Paget'],
#  ['Arthur Pease'],
#  ['Arthur Phayre'],
#  ['Arthur Tappan'],
#  ['Arthur Trevelyan'],
#  ['Arthur Turrell'],
#  ['Arthur Vacher'],
#  ['Arthur William A Beckett'],
#  ['Arthur de Zeltner'],
#  ['Arthurs Club'],
#  ['Arts Club'],
#  ['Arundel Club'],
#  ['Ashton Yates'],
#  ['Association Scientifique de Paris'],
#  ['Association for Promoting the General Welfare of the Blind'],
#  ['Association for the Protection of Homeopathic Students and Practitioners'],
#  ['Athenaeum Club'],
#  ['August Friedrich Marschall von Burgholzhausen'],
#  ['August Hirsch'],
#  ['August Muller'],
#  ['Augustin Weisbach'],
#  ['Augustine Aglio'],
#  ["Augustus D'Este"],
#  ['Augustus E G Perrot'],
#  ['Augustus Goldsmid'],
#  ['Augustus Guest'],
#  ['Augustus H Hunt'],
#  ['Augustus Heinrich Petermann'],
#  ['Augustus Henry Lane Fox later Pitt Rivers'],
#  ['Augustus Jessopp'],
#  ['Augustus S Wilkins'],
#  ['Augustus Wollaston Franks'],
#  ['Austen Henry Layard'],
#  ['Australia'],
#  ['Austria'],
#  ['Austria Hungary'],
#  ['B G Miraglia'],
#  ['B H Paul'],
#  ['B Hewitt'],
#  ['B Slack'],
#  ['Bacup Natural History Society'],
#  ['Balthazar Walter Foster'],
#  ['Barnard Dickinson'],
#  ['Barnet Phillips'],
#  ['Barr Meadows'],
#  ['Bartholomew Bernasconi'],
#  ['Bartholomew Smith'],
#  ['Basil Lovery'],
#  ['Bath Charles Smart'],
#  ['Bath Natural History Society'],
#  ['Bath Royal Literary and Scientific Institution'],
#  ['Bath and County Club'],
#  ['Bayle St John'],
#  ['Bedford Pim'],
#  ['Belgian Academy of Sciences of France'],
#  ['Belgium'],
#  ['Belize'],
#  ['Benbow Backhouse Marson'],
#  ['Benjamin Bond Cabbell'],
#  ['Benjamin Boyd'],
#  ['Benjamin Collins Brodie'],
#  ['Benjamin Hinde'],
#  ['Benjamin Jowett (2)'],
#  ['Benjamin Phillips'],
#  ['Benjamin Robert Winthrop'],
#  ['Benjamin Seebohm'],
#  ['Benjamin Vulliamy'],
#  ['Benjamin Wheeler'],
#  ['Benson Baker'],
#  ['Benson Fryer'],
#  ['Beriah Botfield'],
#  ['Bermuda'],
#  ['Bernard Dorn'],
#  ['Bernard Edward Brodhurst'],
#  ['Bernard Quaritch'],
#  ['Berthold Seemann'],
#  ['Berwickshire Naturalists Field Club'],
#  ['Bev D Hewett'],
#  ['Biblical Archaeological Society'],
#  ['Borneo'],
#  ['Botanical Society of Edinburgh'],
#  ['Botanical Society of London'],
#  ['Brasenose Club'],
#  ['Brasseur de Bourbourg'],
#  ['Brazil'],
#  ['Brian Houghton Hodgson'],
#  ['Brice Smyth'],
#  ['Brinsley Nicholson'],
#  ['Bristol and Gloucester Archaeological Society'],
#  ['British Academy'],
#  ['British Archaeological Association'],
#  ['British Archaeological Society'],
#  ['British Association'],
#  ['British Homeopathic Association'],
#  ['British Homeopathic Society'],
#  ['British Medical Association'],
#  ['British Museum'],
#  ['British Mycological Society'],
#  ['British National Association of Spirtualists'],
#  ['Brookes Club'],
#  ['Brothers Peek'],
#  ['Buchanan Washbourn'],
#  ['Burmah'],
#  ['Burwood Godlee'],
#  ['Buxton Lawrie'],
#  ['C  Poorooshottum Modeliar'],
#  ['C  Treasure Jones'],
#  ['C A Albright'],
#  ['C A Du Val'],
#  ['C Ashby'],
#  ['C B Mosse'],
#  ['C B Robinson'],
#  ['C Baxter'],
#  ['C Clarke'],
#  ['C Clothier'],
#  ['C D Hammond'],
#  ['C D Tolme'],
#  ['C E Harle'],
#  ['C F Howard'],
#  ['C H  Fairfax Ellis'],
#  ['C H Pearson'],
#  ['C Haddison'],
#  ['C Hinchcliffe'],
#  ['C Jervise'],
#  ['C Knight'],
#  ['C Lilgevolch'],
#  ['C Lushington'],
#  ['C M Barter'],
#  ['C Mottley'],
#  ['C Rathbone'],
#  ['C S Tosswill'],
#  ['C Southall'],
#  ['C T Gardner'],
#  ['C W  Bowdler Bell'],
#  ['C Washbourne'],
#  ['Caerleon Antiquarian Association'],
#  ['Caleb Fletcher'],
#  ['Caleb Williams'],
#  ['Cambrian Archaeological Association'],
#  ['Cambrian Archaeological Society'],
#  ['Cambridge Philosophical Society'],
#  ['Camden Society'],
#  ['Camille Bertrand'],
#  ['Camille Dareste'],
#  ['Canada'],
#  ['Cannibal Club'],
#  ['Carl (Karl) Steinhauer'],
#  ['Carl Alphonse Hoffman'],
#  ['Carl Ernst von Baer'],
#  ['Carl Gustav Carus'],
#  ['Carl Ritter'],
#  ['Carl Ritter von Scherzer'],
#  ['Carl Semper'],
#  ['Carl Vogt'],
#  ['Carl Wilhelm Ferdinand Uhde'],
#  ['Carlton Club'],
#  ['Caroline Armistead'],
#  ['Caroline Marriage'],
#  ['Casper W Eddy'],
#  ['Catherine Backhouse'],
#  ['Ceylon'],
#  ['Champion Wetton'],
#  ['Charity Organization Society'],
#  ['Charles (1) Harrison'],
#  ['Charles A Atkins'],
#  ['Charles Adlard'],
#  ['Charles Adolphe Morlot'],
#  ['Charles Alfred Rolph'],
#  ['Charles Atkins'],
#  ['Charles Augustus Ward'],
#  ['Charles B Warner'],
#  ['Charles Bennett'],
#  ['Charles Booth'],
#  ['Charles Brainsford'],
#  ['Charles Brett'],
#  ['Charles Brewin'],
#  ['Charles Buxton'],
#  ['Charles Capper'],
#  ['Charles Cardale Babington'],
#  ['Charles Clark'],
#  ['Charles Cornish Brown'],
#  ['Charles Darwin'],
#  ['Charles Donald Maclean'],
#  ['Charles Duncan Cameron'],
#  ['Charles E Mackintosh'],
#  ['Charles E Russell'],
#  ['Charles E Smith'],
#  ['Charles Edward Gover'],
#  ['Charles Edward Grey'],
#  ['Charles Edward Stewart'],
#  ['Charles Francis Lewis'],
#  ['Charles Frederick Ash'],
#  ['Charles Garrett'],
#  ['Charles Gillett'],
#  ['Charles Groves'],
#  ['Charles Gutzlaff'],
#  ['Charles H L Woodd'],
#  ['Charles Hamond Alpe'],
#  ['Charles Harcourt Chambers'],
#  ['Charles Harding'],
#  ['Charles Henry Bagnall'],
#  ['Charles Henry Fox'],
#  ['Charles Henry Gardner'],
#  ['Charles Henry Gatty'],
#  ['Charles Hicks'],
#  ['Charles Hindley'],
#  ['Charles Holt Bracebridge'],
#  ['Charles Horsnaill'],
#  ['Charles J Harland'],
#  ['Charles James Major'],
#  ['Charles Janson'],
#  ['Charles Jellicoe'],
#  ['Charles Jeremiah Renshaw'],
#  ['Charles Jupe'],
#  ['Charles Kingsley'],
#  ['Charles L Braithwaite'],
#  ['Charles L Harford'],
#  ['Charles Linder'],
#  ['Charles Lionel Showers'],
#  ['Charles Lyell'],
#  ['Charles Malcolm'],
#  ['Charles Napoleon de Cardi'],
#  ['Charles Nice Robertson'],
#  ['Charles Nicholson'],
#  ["Charles O'Callaghan"],
#  ['Charles Ottley Groom Napier'],
#  ['Charles Otto'],
#  ['Charles Pasley'],
#  ['Charles Pickering'],
#  ['Charles Plummer'],
#  ['Charles Pyndar Beauchamp Walker'],
#  ['Charles R Williams'],
#  ['Charles Radcliffe Bond'],
#  ['Charles Rafn'],
#  ['Charles Ratcliff'],
#  ['Charles Reade'],
#  ['Charles Richardson'],
#  ['Charles Robert des Ruffieres'],
#  ['Charles Rogers'],
#  ['Charles Rooke'],
#  ['Charles Rowland Goodman'],
#  ['Charles S Salmon'],
#  ['Charles Scott'],
#  ['Charles Sessions'],
#  ['Charles Sharp Price'],
#  ['Charles Sheffield Dickson'],
#  ['Charles Stenning'],
#  ['Charles Stuart Bailey'],
#  ['Charles Sturge'],
#  ['Charles Sturgeon'],
#  ['Charles Sumner'],
#  ['Charles Thomas Pearce'],
#  ['Charles W Bollaert'],
#  ['Charles Warden'],
#  ['Charles Wentworth Dilke'],
#  ['Charles William Carter Madden Medlicott'],
#  ['Charles William Devis'],
#  ['Charles William Eeles'],
#  ['Charles William Hoyland'],
#  ['Charles Wilson'],
#  ['Charles jun Tuckett'],
#  ['Chemical Society'],
#  ['Child Study Society'],
#  ['Childhood Society'],
#  ['Chile'],
#  ['China'],
#  ['Christian JÃƒÂ¼rgensen Thomsen'],
#  ['Christopher Bowley'],
#  ['Christopher J Barnard'],
#  ['Clarence Harcourt'],
#  ['Claude Buchanan Ker'],
#  ['Clement Jackson'],
#  ['Clements Robert Markham'],
#  ['Colquehoun Club'],
#  ['Connop Thirlwall'],
#  ['Conrad C Dumas'],
#  ['Conrad Eckhard'],
#  ['Conrad Finzel'],
#  ['Conrad Leemans'],
#  ['Conservative Club'],
#  ['Constantine Simonides'],
#  ['Cork Scientific and Literary Society'],
#  ['Cornelieus Prior'],
#  ['Cornelis Swaving'],
#  ['Cornelius Donovan'],
#  ['Cornelius Hanbury'],
#  ['Cornelius Walford'],
#  ['Cornelius x Jun Hanbury'],
#  ['Corporation Library London, City of'],
#  ['Coryndon H Luxmoore'],
#  ['Craig Gibson'],
#  ['Crewe Alston'],
#  ['Culling Eardley Smith'],
#  ['Cumberland and Westmorland Antiquarian and Archaeological Society'],
#  ['Cunningham Borthwick'],
#  ['Cyprus'],
#  ['Cyrus Clark'],
#  ['D  Pye Smith'],
#  ['D Bellock'],
#  ['D Bolton'],
#  ['D Brown'],
#  ['D Dodshon'],
#  ['D G F Macdonald'],
#  ['D G Goyder'],
#  ['D Holmes'],
#  ['D I Drakeford'],
#  ['D J Breuneis'],
#  ['D Lubach'],
#  ['D Miller'],
#  ['D Mitchell'],
#  ['D Nicol'],
#  ['D P Hock'],
#  ['D P Mack'],
#  ['D Tuke'],
#  ['D W Nash'],
#  ['Dadabhai Naoroji'],
#  ['Dallas Hill'],
#  ['Danby Palmer Fry'],
#  ['Daniel Bell Hanbury'],
#  ['Daniel Brooke Robertson'],
#  ['Daniel Cooper'],
#  ['Daniel Doncaster'],
#  ['Daniel Earl Burdett'],
#  ['Daniel Mackintosh'],
#  ['Daniel Maxwell'],
#  ["Daniel O'Connell"],
#  ['Daniel P Hack'],
#  ['Daniel Wheeler'],
#  ['Daniel Wilson'],
#  ['Daniel de Castro'],
#  ['Dashwood G Parry'],
#  ['David Blellock'],
#  ['David Brodie'],
#  ['David Charles'],
#  ['David Dale'],
#  ['David Duncan'],
#  ['David Forbes'],
#  ['David Gay'],
#  ['David Henry Stone'],
#  ['David King'],
#  ['David Kinloch'],
#  ['David Lloyd'],
#  ['David Mackintosh'],
#  ['David Mitchell Henderson'],
#  ['David Morris'],
#  ['David S Price'],
#  ['David Salomons'],
#  ['David Scott'],
#  ['David Sydenham'],
#  ['David Wilson'],
#  ['Davyd William Nash'],
#  ['Deborah Beesley'],
#  ['Deborah Gibson'],
#  ['Deborah Sterry'],
#  ['Denison H Allport'],
#  ['Denmark'],
#  ['Dominican Republic'],
#  ['Dominico Navoni'],
#  ['Don Flores Estrada'],
#  ['Donald Nicoll'],
#  ['Douglas Galton'],
#  ['Draper Mackinder'],
#  ['Dresden Geographical Society'],
#  ['Dunbar Isidore Heath'],
#  ['Duncan W Forbes'],
#  ['E & M Elliott'],
#  ['E A Albright'],
#  ['E Abdy'],
#  ['E Atkinson'],
#  ['E B Tawney'],
#  ['E Backhouse'],
#  ['E Baines'],
#  ['E Bonavia'],
#  ['E Crowley'],
#  ['E F Sewell'],
#  ['E Ford'],
#  ['E Gilkes'],
#  ['E Harris'],
#  ['E J Routh'],
#  ['E J Selwyn'],
#  ['E L Birkbeck'],
#  ['E Mills'],
#  ['E Morris'],
#  ['E Neave'],
#  ['E O Tindale'],
#  ['E P Southall'],
#  ['E Ridley'],
#  ['E S Schwabe'],
#  ['E Sayce'],
#  ['E Schiemann'],
#  ['E Stephens'],
#  ['E T Sewell'],
#  ['E T Wakefield'],
#  ['E Tinsley'],
#  ['E V Gardner'],
#  ['E Walker'],
#  ['ESL'],
#  ['Eardley Childers'],
#  ['Early English Text Society'],
#  ['East India Club'],
#  ['East India United Services Club'],
#  ['Ebenezer Clarke'],
#  ['Ebenezer Elliott'],
#  ['Ebenezer Smith'],
#  ['Eclectic Medical Society of New York'],
#  ['Ecuador'],
#  ['Edgar Musgrove'],
#  ['Edinburgh Gratis Sabbath School Society'],
#  ['Edinburgh Mathematical Society'],
#  ['Edmund Backhouse'],
#  ['Edmund Buxton'],
#  ['Edmund Farmer'],
#  ['Edmund Francis Davis'],
#  ['Edmund Gurney'],
#  ['Edmund J Bridell'],
#  ['Edmund Jeffries'],
#  ['Edmund Lloyd'],
#  ['Edmund Lucas'],
#  ['Edmund Patterson'],
#  ['Edmund Sturge'],
#  ['Edmund Walker'],
#  ['Edmund Walter Coleman'],
#  ['Edouard J Villin'],
#  ['Edouard Lartet'],
#  ['Edward (1) Lawrence'],
#  ['Edward A Crouch'],
#  ['Edward A Leatham'],
#  ['Edward Andrew Trevor'],
#  ['Edward Arnold'],
#  ['Edward Ash'],
#  ['Edward B Bogg'],
#  ['Edward B Harbour'],
#  ['Edward Backhouse'],
#  ['Edward Barrett Hodges Curteis'],
#  ['Edward Beck'],
#  ['Edward Bellamy'],
#  ['Edward Bickerton Evans'],
#  ['Edward Brown'],
#  ['Edward C Anderson'],
#  ['Edward C May'],
#  ['Edward Carroll'],
#  ['Edward Charles Healey'],
#  ['Edward Charlesworth'],
#  ['Edward Everett'],
#  ['Edward Gardiner Fishbourne'],
#  ['Edward Greey'],
#  ['Edward Gurney'],
#  ['Edward Hooper May'],
#  ['Edward Jackson Riccard'],
#  ['Edward James'],
#  ['Edward John Eyre'],
#  ['Edward John Morshead'],
#  ['Edward Jun Backhouse'],
#  ['Edward Lawford'],
#  ['Edward Lord'],
#  ['Edward Lucas'],
#  ['Edward Lund'],
#  ['Edward Marsh'],
#  ['Edward Martin'],
#  ['Edward Meryon'],
#  ['Edward Morris'],
#  ['Edward Murray'],
#  ['Edward North Buxton'],
#  ['Edward North Clifton'],
#  ["Edward O'Riley"],
#  ['Edward Osborne Smith'],
#  ['Edward Paull'],
#  ['Edward Peacock'],
#  ['Edward Pease'],
#  ['Edward Pick'],
#  ['Edward Price Houghton'],
#  ['Edward Priestman'],
#  ['Edward Priestman (2)'],
#  ['Edward Richardson'],
#  ['Edward Robinson'],
#  ['Edward Rowley Morris'],
#  ['Edward Ryan'],
#  ['Edward Smith'],
#  ['Edward Spooner'],
#  ['Edward St Maur'],
#  ['Edward Stamp'],
#  ['Edward Sturman'],
#  ['Edward Taylor'],
#  ['Edward Tenison Ryan Tenison'],
#  ['Edward Thomas'],
#  ['Edward Thurlow'],
#  ['Edward V Maur'],
#  ['Edward W Martin'],
#  ['Edward W Murphy'],
#  ['Edward Warner'],
#  ['Edward William Brabrook'],
#  ['Edward Wood'],
#  ['Edwd Harris'],
#  ['Edwin Bracher'],
#  ['Edwin Brown'],
#  ['Edwin C Suttor'],
#  ['Edwin Chadwick'],
#  ['Edwin Foxton Firby'],
#  ['Edwin Goadby'],
#  ['Edwin Henry Baverstock'],
#  ['Edwin Holborow King'],
#  ['Edwin Lander'],
#  ['Edwin Lee'],
#  ['Edwin Ormond Brown'],
#  ['Edwin Ransom'],
#  ['Egerton Ryerson'],
#  ['Egypt'],
#  ['Eliza Barclay'],
#  ['Eliza Bell'],
#  ['Eliza Post'],
#  ['Elizabeth Allen'],
#  ['Elizabeth Bowley'],
#  ['Elizabeth Charelton'],
#  ['Elizabeth Dyer'],
#  ['Elizabeth F Gibson'],
#  ['Elizabeth G Dimsdale'],
#  ['Elizabeth Hills'],
#  ['Elizabeth Howard'],
#  ['Elizabeth Howard (2)'],
#  ['Elizabeth Priestman'],
#  ['Elizabeth S Dawes'],
#  ['Elizabeth Tuckett'],
#  ['Elliott Cresson'],
#  ['Emil Arnold Praeger'],
#  ['Emile Duhousset'],
#  ['Emma Letchworth'],
#  ['Enrico Hillyer Giglioli'],
#  ['Entomological Society of London'],
#  ['Ephraim George Squier'],
#  ['Erasmus (Ras) Darwin'],
#  ['Eric Williams'],
#  ['Ernest Abraham Hart'],
#  ['Ernest Bates'],
#  ['Ernest Dieffenbach'],
#  ['Ernest Renan'],
#  ['Ernst Hallier'],
#  ['Ernst Juch'],
#  ['Ernst Wilhelm Ritter von Brucke'],
#  ['Erskine Perry'],
#  ['Escott Chambers'],
#  ['Essex Field Club'],
#  ['Esther Beecham'],
#  ['Estrade Flores'],
#  ['Ethiopia'],
#  ['Ethnological Society, New York'],
#  ['Ethnological Society, Paris'],
#  ['Etienne Gustave Mery'],
#  ['Eugene Dally'],
#  ['Eugene Morris'],
#  ['Evan Powell Meredith'],
#  ['Evert Julius Bonsdorff'],
#  ['Ex Libris Society'],
#  ['F  Drummond Davies'],
#  ['F  E Gibson'],
#  ['F  Henry Wood'],
#  ['F Allen'],
#  ['F B  Bernard Natusch'],
#  ['F C Dowley'],
#  ['F G Courthope'],
#  ['F Good'],
#  ['F H Fitzwilliam'],
#  ['F H Hobler'],
#  ['F H Janson'],
#  ['F Hudson'],
#  ['F J Atkins'],
#  ['F J Bett'],
#  ['F J Thompson'],
#  ['F J Walker'],
#  ['F L Cotton'],
#  ['F Maitland Innes'],
#  ['F R Priestman'],
#  ['F Seebohm'],
#  ['F Squire'],
#  ['F T Littey'],
#  ['F Taylor'],
#  ['F W Chesson'],
#  ['F W Coates'],
#  ['F W Harrer'],
#  ['F W Newman'],
#  ['F W Ricketts'],
#  ['F Woodhead'],
#  ['Facundo Carulla'],
#  ['Fanny Backhouse'],
#  ['Felix Garden'],
#  ['Fenwick T Poole'],
#  ['Ferdinand Muller'],
#  ['Ferdinand Vandeveer Hayden'],
#  ['Ferdinand Von Wrangell'],
#  ['Fererra Pinheiro'],
#  ['Field Naturalists Club of Victoria'],
#  ['Fielden Thorpe'],
#  ['Filippo Manetta'],
#  ['Finland'],
#  ['Flaxman Spurrell'],
#  ['Folklore Society'],
#  ['Forster Fryer'],
#  ['Fortescue John Morgan'],
#  ['Fr Groth'],
#  ['France'],
#  ['Frances Wright'],
#  ['Francis Alex (Frank) Wenham'],
#  ['Francis Beresford Wright'],
#  ['Francis Brown'],
#  ['Francis Campbell'],
#  ['Francis Campin'],
#  ['Francis Duncan'],
#  ['Francis E Fox'],
#  ['Francis Egerton'],
#  ['Francis G P Neison'],
#  ['Francis Galton'],
#  ['Francis George Cornelius Wolber'],
#  ['Francis Gibson'],
#  ['Francis Griffiths'],
#  ['Francis Ignatio Rickard'],
#  ['Francis Kerridge Munton'],
#  ['Francis Lloyd'],
#  ['Francis May'],
#  ['Francis R Spry'],
#  ['Francis Richardson'],
#  ['Francis Tagart'],
#  ['Francis Tuckett'],
#  ['Francis Wright'],
#  ['Francisco Delgado Jugo'],
#  ['Francisco E Pereira'],
#  ['Franciscus Miklosich'],
#  ['Francois Jules Pictet'],
#  ['Frank Calvert'],
#  ['Frank Carr Beard'],
#  ['Frank Chance'],
#  ['Frank J Husband'],
#  ['Frank Ramsay'],
#  ['Frank Simpson'],
#  ['Frank William Breach'],
#  ['Frank Wilson'],
#  ['Frank Wrentmore'],
#  ['Franklin Thomas Richards'],
#  ['FranÃƒÂ§ois Louis Nompar de Caumont La Force Castelnau'],
#  ['Fred Thompson'],
#  ['Frederick A B Crawfurd'],
#  ['Frederick Alexander'],
#  ['Frederick Ashby'],
#  ['Frederick Augustus Haserick'],
#  ['Frederick Baines'],
#  ['Frederick Bower'],
#  ['Frederick Braby'],
#  ['Frederick Brome'],
#  ['Frederick Butler Montgomerie'],
#  ['Frederick Chatfield'],
#  ['Frederick Cock'],
#  ['Frederick Cooper'],
#  ['Frederick Crowley'],
#  ['Frederick Duckworth'],
#  ['Frederick E Davis'],
#  ['Frederick Edmund Blyth'],
#  ['Frederick Edward Pearse'],
#  ['Frederick Fearon'],
#  ['Frederick Firebrace'],
#  ['Frederick Fryer'],
#  ['Frederick George Hilton Price'],
#  ['Frederick George Lee'],
#  ['Frederick George Shaw'],
#  ['Frederick Green'],
#  ['Frederick Griffin'],
#  ['Frederick H Fox'],
#  ['Frederick Henry Scott'],
#  ['Frederick Hindmarsh'],
#  ['Frederick Hovenden'],
#  ['Frederick J Bell'],
#  ['Frederick John Jeffery'],
#  ['Frederick King Green'],
#  ['Frederick Lawrence'],
#  ['Frederick Lucas'],
#  ['Frederick Mackenzie Skues'],
#  ['Frederick Martin Williams'],
#  ['Frederick Ouvry'],
#  ['Frederick R Izard'],
#  ['Frederick Scott Archer'],
#  ['Frederick Snaith'],
#  ['Frederick Stanley Carpenter'],
#  ['Frederick Theed'],
#  ['Frederick Thompson'],
#  ['Frederick Travers'],
#  ['Frederick Tuckett'],
#  ['Frederick W Aley'],
#  ['Frederick W Rogers'],
#  ['Frederick Wells'],
#  ['Frederick Wheeler'],
#  ['Frederick Whittock Darby'],
#  ['Frederick William Cosens'],
#  ['Frederick William Hope'],
#  ['Frederick William Monk'],
#  ['Frederick William Rudler'],
#  ['Frederick Wills'],
#  ['Friedrich Max Muller'],
#  ['G  Jasper Nicholls'],
#  ['G  Wythes Daniell'],
#  ['G A Forteath'],
#  ['G A Hutchinson'],
#  ['G A Robinson'],
#  ['G B Holmes'],
#  ['G C Rankin'],
#  ['G E Richardson'],
#  ['G F Angas'],
#  ['G F Whidbourne'],
#  ['G Grimshaw'],
#  ['G H Ogston'],
#  ['G J D Heath'],
#  ['G J Gibson'],
#  ['G Kasimates'],
#  ['G M Tagore'],
#  ['G Macgowan'],
#  ['G N Mussabini'],
#  ['G P Dall'],
#  ['G Pritchard'],
#  ['G R Pumphrey'],
#  ['G Ralston'],
#  ['G S Brady'],
#  ['G T Day'],
#  ['G W Alexander'],
#  ['G W Spence'],
#  ['G Williamson'],
#  ['G van der Maalen'],
#  ['G van der Maerlen'],
#  ['Garrick Club'],
#  ['Geo Holmes'],
#  ['Geographical Society of Paris'],
#  ['Geological Society'],
#  ['Geological Society of France'],
#  ["Geologist's Association"],
#  ['George (1) Campbell'],
#  ['George (1) Smith'],
#  ['George (2) Campbell'],
#  ['George (2) Smith'],
#  ['George Abbott'],
#  ['George Alexander James'],
#  ['George Allin'],
#  ['George Amner'],
#  ['George Atkinson'],
#  ['George Augustus Frederick Ruxton'],
#  ['George Augustus Robinson'],
#  ['George Balfour'],
#  ['George Bellas Greenough'],
#  ['George Bertram'],
#  ['George Blagrove Snell'],
#  ['George Bonavia'],
#  ['George Bonham'],
#  ['George Boulton'],
#  ['George Bryant'],
#  ['George Busk'],
#  ['George Byham'],
#  ['George Byrne Lee'],
#  ['George C Thompson'],
#  ['George Calvert'],
#  ['George Carter'],
#  ['George Catlin'],
#  ['George Christie'],
#  ['George Cook'],
#  ['George Cooke'],
#  ['George Courthope Green'],
#  ['George Critchett'],
#  ['George Crosfield'],
#  ['George Curling Joad'],
#  ['George Cutler'],
#  ['George Dalhousie Ramsay'],
#  ['George Dawson'],
#  ['George Denman'],
#  ['George Dennis'],
#  ['George Dibley'],
#  ['George Duncan Gibb'],
#  ['George E Roberts'],
#  ['George Edgeworth Fenwick'],
#  ['George Fleming'],
#  ['George Folsom'],
#  ['George Ford Copeland'],
#  ['George Fox'],
#  ['George Frederick Rolph'],
#  ['George Granville Francis Egerton'],
#  ['George Grenfell Glyn'],
#  ['George Grey'],
#  ['George H Pope'],
#  ['George Hawkins'],
#  ['George Head'],
#  ['George Henry Daw'],
#  ...]

# %%
edges
# Out:
# [('Arthur William A Beckett', 'ASL'),
#  ('Arthur William A Beckett', 'London'),
#  ('Arthur William A Beckett', 'literary'),
#  ('Andrew Mercer Adam', 'ASL'),
#  ('Andrew Mercer Adam', 'armed services'),
#  ('Andrew Mercer Adam', 'country'),
#  ('Andrew Mercer Adam', 'medical'),
#  ('H R Adam', 'AI'),
#  ('H R Adam', 'ASL'),
#  ('H R Adam', 'Africa'),
#  ('William Adam', 'ESL'),
#  ('William Adam', 'political'),
#  ('Henry John Adams', 'ASL'),
#  ('Henry John Adams', 'London'),
#  ('William (1) Adams', 'Athenaeum Club'),
#  ('William (1) Adams', 'ESL'),
#  ('William (2) Adams', 'AI'),
#  ('William (2) Adams', 'ESL'),
#  ('William (2) Adams', 'London'),
#  ('William (2) Adams', 'Medical Society of London'),
#  ('William (2) Adams', 'Medical and Chirurgical Society of London'),
#  ('William (2) Adams', 'Pathological Society of London'),
#  ('William (2) Adams', 'Royal College of Surgeons'),
#  ('William (2) Adams', 'medical'),
#  ('William Adlam', 'ASL'),
#  ('William Adlam', 'Somersetshire Archaeological and Natural History Society'),
#  ('William Adlam', 'country'),
#  ('Louis Agassiz', 'AI'),
#  ('Louis Agassiz', 'ASL'),
#  ('Louis Agassiz', 'America'),
#  ('Louis Agassiz', 'ESL'),
#  ('Louis Agassiz', 'academic'),
#  ('Louis Agassiz', 'biologist'),
#  ('Louis Agassiz', 'geologist'),
#  ('Anastasius Agathides', 'ASL'),
#  ('Anastasius Agathides', 'London'),
#  ('Anastasius Agathides', 'academic'),
#  ('Augustine Aglio', 'ESL'),
#  ('Augustine Aglio', 'artist'),
#  ('Joseph Agnew', 'ASL'),
#  ('Joseph Agnew', 'Scotland'),
#  ('Joseph Agnew', 'medical'),
#  ('William Francis Harrison Ainsworth', 'ESL'),
#  ('William Francis Harrison Ainsworth', 'Geological Society'),
#  ('William Francis Harrison Ainsworth', 'London'),
#  ('William Francis Harrison Ainsworth', 'Royal Geographical Society'),
#  ('William Francis Harrison Ainsworth', 'Society of Antiquaries'),
#  ('William Francis Harrison Ainsworth', 'Syro Egyptian Society'),
#  ('William Francis Harrison Ainsworth', 'academic'),
#  ('William Francis Harrison Ainsworth', 'medical'),
#  ('William Baird Airston', 'ASL'),
#  ('William Baird Airston', 'Royal College of Surgeons'),
#  ('William Baird Airston', 'Scotland'),
#  ('William Baird Airston', 'medical'),
#  ('Alexander Muirhead Aitken', 'AI'),
#  ('Alexander Muirhead Aitken', 'ESL'),
#  ('Alexander Muirhead Aitken', 'India'),
#  ('Alexander Muirhead Aitken', 'London'),
#  ('Alexander Muirhead Aitken', 'legal'),
#  ('Thomas Aitken', 'ASL'),
#  ('Thomas Aitken', 'Anthropological Society of Paris'),
#  ('Thomas Aitken', 'Medico Psychological Association'),
#  ('Thomas Aitken', 'Scotland'),
#  ('Thomas Aitken', 'medical'),
#  ('Rutherford Alcock', 'Athenaeum Club'),
#  ('Rutherford Alcock', 'China'),
#  ('Rutherford Alcock', 'ESL'),
#  ('Rutherford Alcock', 'Japan'),
#  ('Rutherford Alcock', 'diplomacy'),
#  ('William Aldam', 'APS'),
#  ('William Aldam', 'ESL'),
#  ('William Aldam', 'Quaker'),
#  ('William Aldam', 'country'),
#  ('William Aldam', 'political'),
#  ('Frederick W Aley', 'ASL'),
#  ('Frederick W Aley', 'London'),
#  ('Frederick W Aley',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('J  McGrigor Allan', 'ASL'),
#  ('J  McGrigor Allan', 'London'),
#  ('J  McGrigor Allan', 'literary'),
#  ('S  Stafford Allen', 'APS'),
#  ('S  Stafford Allen', 'ASL'),
#  ('S  Stafford Allen', 'Egypt'),
#  ('S  Stafford Allen', 'London'),
#  ('S  Stafford Allen', 'Quaker'),
#  ('S  Stafford Allen', 'civil engineer'),
#  ('William Allen', 'APS'),
#  ('William Allen', 'ESL'),
#  ('William Allen', 'QCA'),
#  ('William Allen', 'armed services'),
#  ('George Allin', 'ASL'),
#  ('George Allin', 'London'),
#  ('George Allin', 'country'),
#  ('Charles Hamond Alpe', 'ASL'),
#  ('Charles Hamond Alpe', 'London'),
#  ('Crewe Alston', 'ASL'),
#  ('Crewe Alston', 'London'),
#  ('William Amhurst Tyssen Amhurst', 'AI'),
#  ('William Amhurst Tyssen Amhurst', 'Athenaeum Club'),
#  ('William Amhurst Tyssen Amhurst', 'Carlton Club'),
#  ('William Amhurst Tyssen Amhurst', 'ESL'),
#  ('William Amhurst Tyssen Amhurst', 'Marlborough Club'),
#  ('William Amhurst Tyssen Amhurst', 'Royal Society of Literature'),
#  ('William Amhurst Tyssen Amhurst', 'Society of Antiquaries'),
#  ('William Amhurst Tyssen Amhurst', 'collector'),
#  ('William Amhurst Tyssen Amhurst', 'country'),
#  ('William Amhurst Tyssen Amhurst', 'political'),
#  ('George Amner', 'ASL'),
#  ('George Amner', 'business'),
#  ('George Amner', 'country'),
#  ('Edward C Anderson', 'ASL'),
#  ('Edward C Anderson', 'London'),
#  ('Edward C Anderson', 'Royal College of Surgeons'),
#  ('Edward C Anderson', 'medical'),
#  ('John Anderson', 'ASL'),
#  ('John Anderson', 'Linnean Society of London'),
#  ('John Anderson', 'armed services'),
#  ('John Anderson', 'country'),
#  ('John Anderson', 'medical'),
#  ('Joseph Anderson', 'ASL'),
#  ('Joseph Anderson', 'Scotland'),
#  ('Joseph Anderson', 'Society of Antiquaries of Scotland'),
#  ('Joseph Anderson', 'archaeologist'),
#  ('Joseph Anderson', 'editor'),
#  ('Joseph Anderson', 'educator'),
#  ('Joseph Anderson', 'museum work'),
#  ('W  P Andrew', 'ESL'),
#  ('x Andrews', 'ESL'),
#  ('Matthew John Anketell', 'ESL'),
#  ('Matthew John Anketell', 'London'),
#  ('Thomas Chisholm Anstey', 'ESL'),
#  ('Thomas Chisholm Anstey', 'Hong Kong'),
#  ('Thomas Chisholm Anstey', 'London'),
#  ('Thomas Chisholm Anstey', 'legal'),
#  ('Thomas Chisholm Anstey', 'political'),
#  ('x Antrim', 'AI'),
#  ('x Antrim', 'ESL'),
#  ('x Antrim', 'Ireland'),
#  ('x Antrim', 'aristocracy'),
#  ('x Antrim', 'country'),
#  ('William Appleyard', 'AI'),
#  ('William Appleyard', 'ESL'),
#  ('William Appleyard', 'church'),
#  ('William Appleyard', 'country'),
#  ('William Arbuthnot', 'AI'),
#  ('William Arbuthnot', 'ASL'),
#  ('William Arbuthnot', 'London'),
#  ('William Arbuthnot', 'Oriental Club'),
#  ('Frederick Scott Archer', 'ESL'),
#  ('Frederick Scott Archer', 'country'),
#  ('Frederick Scott Archer', 'inventor'),
#  ('Frederick Scott Archer', 'photographer'),
#  ('Richard Edward Arden', 'ASL'),
#  ('Richard Edward Arden', 'Acclimatisation Society'),
#  ('Richard Edward Arden', 'Geological Society'),
#  ('Richard Edward Arden', 'Junior Athenaeum Club'),
#  ('Richard Edward Arden', 'National Club'),
#  ('Richard Edward Arden', 'Ornithological Society'),
#  ('Richard Edward Arden', 'Royal Geographical Society'),
#  ('Richard Edward Arden', 'country'),
#  ('Richard Edward Arden', 'legal'),
#  ('Alexander Aria', 'ASL'),
#  ('Alexander Aria', 'London'),
#  ('William Armitage', 'AI'),
#  ('William Armitage', 'ASL'),
#  ('William Armitage',
#   'Association for the Protection of Homeopathic Students and Practitioners'),
#  ('William Armitage', 'business'),
#  ('William Armitage', 'country'),
#  ('T  B Armitstead', 'ASL'),
#  ('William Armstrong', 'AI'),
#  ('William Armstrong', 'Athenaeum Club'),
#  ('William Armstrong', 'ESL'),
#  ('William Armstrong', 'London'),
#  ('William Armstrong', 'Royal Society'),
#  ('William Armstrong', 'aristocracy'),
#  ('William Armstrong', 'business'),
#  ('William Armstrong', 'country'),
#  ('Edward Arnold', 'ASL'),
#  ('Edward Arnold', 'Chemical Society'),
#  ('Edward Arnold', 'Phrenological Society'),
#  ('Edward Arnold', 'country'),
#  ('Richard Arnold', 'AI'),
#  ('Richard Arnold', 'ASL'),
#  ('Richard Arnold', 'America'),
#  ('Richard Arnold', 'American Medical Association'),
#  ('Richard Arnold', 'Georgia Historical Society'),
#  ('Richard Arnold', 'medical'),
#  ('William Arthur', 'AI'),
#  ('William Arthur', 'ASL'),
#  ('William Arthur', 'ESL'),
#  ('William Arthur', 'Ireland'),
#  ('William Arthur', 'London'),
#  ('William Arthur', 'Royal Asiatic Society'),
#  ('William Arthur', 'church'),
#  ('William Arthur', 'literary'),
#  ('Rodolph Arundell', 'ASL'),
#  ('Rodolph Arundell', 'London'),
#  ('Isidore Ascher', 'ASL'),
#  ('Isidore Ascher', 'London'),
#  ('Isidore Ascher', 'literary'),
#  ('Isidore Ascher', 'poet'),
#  ('Charles Frederick Ash', 'AI'),
#  ('Charles Frederick Ash', 'ASL'),
#  ('Charles Frederick Ash', 'London'),
#  ('Charles Frederick Ash', 'business'),
#  ('James Ashbury', 'ASL'),
#  ('James Ashbury', 'ESL'),
#  ('James Ashbury', 'London'),
#  ('James Ashbury', 'political'),
#  ('John Ashbury', 'ASL'),
#  ('John Ashbury', 'London'),
#  ('William Henry Ashurst', 'AI'),
#  ('William Henry Ashurst', 'Arts Club'),
#  ('William Henry Ashurst', 'ESL'),
#  ('William Henry Ashurst', 'London'),
#  ('William Henry Ashurst', 'Reform Club'),
#  ('William Henry Ashurst', 'legal'),
#  ('Henry Ashworth', 'ESL'),
#  ('Henry Ashworth',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('Henry Ashworth', 'business'),
#  ('Henry Ashworth', 'country'),
#  ('William Aspull', 'ASL'),
#  ('William Aspull', 'London'),
#  ('William Aspull', 'music'),
#  ('John Atcherley', 'ASL'),
#  ('John Atcherley', 'Royal College of Physicians'),
#  ('John Atcherley', 'country'),
#  ('John Atcherley', 'medical'),
#  ('Charles Atkins', 'AI'),
#  ('Charles Atkins', 'ASL'),
#  ('Charles Atkins', 'London'),
#  ('Charles A Atkins', 'ESL'),
#  ('Charles A Atkins', 'country'),
#  ('E Atkinson', 'ESL'),
#  ('E Atkinson', 'country'),
#  ('George Atkinson', 'AI'),
#  ('George Atkinson', 'ASL'),
#  ('George Atkinson', 'Surrey Archaeological Society'),
#  ('George Atkinson', 'country'),
#  ('Alfred Aubert', 'ASL'),
#  ('Alfred Aubert', 'London'),
#  ('Alois Auer', 'Austria'),
#  ('Alois Auer', 'ESL'),
#  ('Alois Auer', 'inventor'),
#  ('Arthur Daniel Aulton', 'ESL'),
#  ('Arthur Daniel Aulton', 'country'),
#  ('Charles Cardale Babington', 'AI'),
#  ('Charles Cardale Babington', 'ASL'),
#  ('Charles Cardale Babington', 'Athenaeum Club'),
#  ('Charles Cardale Babington', 'Cambridge Philosophical Society'),
#  ('Charles Cardale Babington', 'Geological Society'),
#  ('Charles Cardale Babington', 'Linnean Society of London'),
#  ('Charles Cardale Babington', 'Royal Society'),
#  ('Charles Cardale Babington', 'Society of Antiquaries'),
#  ('Charles Cardale Babington',
#   'Somersetshire Archaeological and Natural History Society'),
#  ('Charles Cardale Babington', 'academic'),
#  ('Charles Cardale Babington', 'archaeologist'),
#  ('Charles Cardale Babington', 'botanist'),
#  ('Charles Cardale Babington', 'country'),
#  ('William Babington', 'ASL'),
#  ('William Babington', 'Africa'),
#  ('William Babington', 'London'),
#  ('William Babington', 'Royal Geographical Society'),
#  ('Edward Backhouse', 'AI'),
#  ('Edward Backhouse', 'APS'),
#  ('Edward Backhouse', 'ESL'),
#  ('Edward Backhouse', 'Quaker'),
#  ('Edward Backhouse', 'business'),
#  ('Edward Backhouse', 'church'),
#  ('Edward Backhouse', 'country'),
#  ('James (1) Backhouse', 'APS'),
#  ('James (1) Backhouse', 'ESL'),
#  ('James (1) Backhouse', 'Quaker'),
#  ('James (1) Backhouse', 'academic'),
#  ('James (1) Backhouse', 'church'),
#  ('James (1) Backhouse', 'country'),
#  ('Carl Ernst von Baer', 'AI'),
#  ('Carl Ernst von Baer', 'ASL'),
#  ('Carl Ernst von Baer', 'Anthropological Society of Paris'),
#  ('Carl Ernst von Baer', 'ESL'),
#  ('Carl Ernst von Baer', 'Russia'),
#  ('Carl Ernst von Baer', 'Russian Entomological Society'),
#  ('Carl Ernst von Baer', 'Russian Geographical Society'),
#  ('Carl Ernst von Baer', 'academic'),
#  ('Carl Ernst von Baer', 'explorer'),
#  ('John Bagehot', 'ESL'),
#  ("Walter ('Badgett') Bagehot", 'AI'),
#  ("Walter ('Badgett') Bagehot", 'Athenaeum Club'),
#  ("Walter ('Badgett') Bagehot", 'ESL'),
#  ("Walter ('Badgett') Bagehot", 'London'),
#  ("Walter ('Badgett') Bagehot", 'business'),
#  ("Walter ('Badgett') Bagehot", 'literary'),
#  ('Charles Henry Bagnall', 'ASL'),
#  ('Charles Henry Bagnall', 'country'),
#  ('Charles Stuart Bailey', 'ASL'),
#  ('Charles Stuart Bailey', 'London'),
#  ('Charles Stuart Bailey', 'country'),
#  ('John Bailey', 'APS'),
#  ('John Bailey', 'Ceylon'),
#  ('John Bailey', 'administrative'),
#  ('John Bailey (2)', 'ASL'),
#  ('John Bailey (2)', 'country'),
#  ('James Bain', 'AI'),
#  ('James Bain', 'ASL'),
#  ('James Bain', 'Junior Carlton Club'),
#  ('James Bain', 'Scotland'),
#  ('Thomas Baines', 'APS'),
#  ('Thomas Baines', 'London'),
#  ('Thomas Baines', 'artist'),
#  ('Thomas Baines', 'explorer'),
#  ('Benson Baker', 'ASL'),
#  ('Benson Baker', 'London'),
#  ('Benson Baker', 'Royal College of Physicians'),
#  ('Benson Baker', 'Royal College of Surgeons Edinburgh'),
#  ('Benson Baker', 'medical'),
#  ('J P Baker', 'ASL'),
#  ('J P Baker', 'London'),
#  ('J P Baker', 'Royal College of Surgeons'),
#  ('J P Baker', 'medical'),
#  ('John Baker', 'AI'),
#  ('John Baker', 'APS'),
#  ('John Baker', 'ESL'),
#  ('John Baker', 'London'),
#  ('John Baker', 'political'),
#  ('Samuel C Baker', 'AI'),
#  ('Samuel C Baker', 'APS'),
#  ('Samuel C Baker', 'Africa'),
#  ('Samuel C Baker', 'Athenaeum Club'),
#  ('Samuel C Baker', 'Ceylon'),
#  ('Samuel C Baker', 'ESL'),
#  ('Samuel C Baker', 'London'),
#  ('Samuel C Baker', 'Royal Geographical Society'),
#  ('Samuel C Baker', 'Royal Society'),
#  ('Samuel C Baker', 'administrative'),
#  ('Samuel C Baker', 'country'),
#  ('Samuel C Baker', 'explorer'),
#  ('William Bailey Baker', 'AI'),
#  ('William Bailey Baker', 'ESL'),
#  ('William Bailey Baker', 'New Zealand'),
#  ('George Balfour', 'AI'),
#  ('George Balfour', 'Athenaeum Club'),
#  ('George Balfour', 'ESL'),
#  ('George Balfour', 'London'),
#  ('George Balfour', 'Royal Geographical Society'),
#  ('George Balfour', 'armed services'),
#  ('George Balfour', 'political'),
#  ('John Bannister', 'ESL'),
#  ('John Bannister', 'church'),
#  ('John Bannister', 'country'),
#  ('Henry Barber', 'ASL'),
#  ('Henry Barber', 'Royal College of Physicians'),
#  ('Henry Barber', 'country'),
#  ('Henry Barber', 'medical'),
#  ('Robert Baring', 'ASL'),
#  ('Robert Baring', 'London'),
#  ('Robert Baring', 'armed services'),
#  ('Henry Walter Barlow', 'ASL'),
#  ('Henry Walter Barlow', 'London'),
#  ('Henry Walter Barlow', 'country'),
#  ('Christopher J Barnard', 'ASL'),
#  ('Christopher J Barnard', 'Africa'),
#  ('Christopher J Barnard', 'armed services'),
#  ('Henry Thorowgood Barnes', 'APS'),
#  ('Henry Thorowgood Barnes', 'ASL'),
#  ('Henry Thorowgood Barnes', 'London'),
#  ('Henry Thorowgood Barnes', 'business'),
#  ('John  Wheeldon Barnes', 'AI'),
#  ('John  Wheeldon Barnes', 'ESL'),
#  ('John  Wheeldon Barnes', 'Society of Antiquaries'),
#  ('John  Wheeldon Barnes', 'banker'),
#  ('John  Wheeldon Barnes', 'country'),
#  ('Robert Barnewall', 'ESL'),
#  ('Robert Barnewall', 'armed services'),
#  ('Joseph Henry Barr', 'ASL'),
#  ('Joseph Henry Barr', 'Royal College of Surgeons'),
#  ('Joseph Henry Barr', 'country'),
#  ('Joseph Henry Barr', 'medical'),
#  ('William Roby Barr', 'AI'),
#  ('William Roby Barr', 'ASL'),
#  ('William Roby Barr', 'Geological Society'),
#  ('William Roby Barr', 'business'),
#  ('William Roby Barr', 'country'),
#  ('Thomas Squire Barrett', 'AI'),
#  ('Thomas Squire Barrett', 'ASL'),
#  ('Thomas Squire Barrett', 'New Athenaeum Club'),
#  ('Thomas Squire Barrett', 'Royal Historical Society'),
#  ('Thomas Squire Barrett', 'Royal Society of British Sculptors'),
#  ('Thomas Squire Barrett', 'Statistical Society'),
#  ('Thomas Squire Barrett', 'Zoological Society'),
#  ('Thomas Squire Barrett', 'country'),
#  ('George William Barrington', 'AI'),
#  ('George William Barrington', 'ASL'),
#  ('George William Barrington', 'Geological Society'),
#  ('George William Barrington', 'London'),
#  ('George William Barrington', 'Royal Geographical Society'),
#  ('George William Barrington', 'aristocracy'),
#  ('George William Barrington', 'armed services'),
#  ('George William Barrington', 'political'),
#  ('C M Barter', 'ASL'),
#  ('C M Barter', 'country'),
#  ('C M Barter', 'medical'),
#  ('William Edward Bartlett', 'AI'),
#  ('William Edward Bartlett', 'ASL'),
#  ('William Edward Bartlett', 'London'),
#  ('William Edward Bartlett', 'Society of Antiquaries'),
#  ('Alfred Barton', 'ASL'),
#  ('Alfred Barton', 'London'),
#  ('Alfred Barton', 'Oriental Club'),
#  ('Alfred Barton', 'Royal Geographical Society'),
#  ('Alfred Barton', 'medical'),
#  ('John Stothert Bartrum', 'AI'),
#  ('John Stothert Bartrum', 'ESL'),
#  ('John Stothert Bartrum', 'Royal College of Surgeons'),
#  ('John Stothert Bartrum', 'country'),
#  ('John Stothert Bartrum', 'medical'),
#  ('Adolf Bastian', 'ESL'),
#  ('Adolf Bastian', 'Germany'),
#  ('Adolf Bastian', 'academic'),
#  ('Adolf Bastian', 'museum work'),
#  ('Thomas Bateman', 'ESL'),
#  ('Thomas Bateman', 'antiquarian'),
#  ('Thomas Bateman', 'archaeologist'),
#  ('Thomas Bateman', 'country'),
#  ('Ernest Bates', 'ASL'),
#  ('Ernest Bates', 'architect'),
#  ('Ernest Bates', 'civil engineer'),
#  ('Ernest Bates', 'country'),
#  ('William Battye', 'AI'),
#  ('William Battye', 'ASL'),
#  ('William Battye', 'Royal College of Surgeons'),
#  ('William Battye', 'Royal Horticultural Society of London'),
#  ('William Battye', 'country'),
#  ('William Battye', 'medical'),
#  ('Edwin Henry Baverstock', 'ASL'),
#  ('Edwin Henry Baverstock', 'London'),
#  ('Edwin Henry Baverstock', 'Royal Society of Literature'),
#  ('Edwin Henry Baverstock', 'business'),
#  ('James Bainbridge Baxter', 'ASL'),
#  ('James Bainbridge Baxter', 'London'),
#  ('James Bainbridge Baxter', 'Royal College of Surgeons'),
#  ('James Bainbridge Baxter', 'Society of Antiquaries'),
#  ('Thomas Henry Baylis', 'ESL'),
#  ('Thomas Henry Baylis', 'London'),
#  ('Samuel Beal', 'ASL'),
#  ('Samuel Beal', 'Royal Asiatic Society'),
#  ('Samuel Beal', 'armed services'),
#  ('Samuel Beal', 'church'),
#  ('Samuel Beal', 'country'),
#  ('John S Beale', 'ASL'),
#  ('John S Beale', 'London'),
#  ('Lionel John Beale', 'ESL'),
#  ('Lionel John Beale', 'London'),
#  ('Lionel John Beale', 'Royal College of Surgeons'),
#  ('Lionel John Beale', 'Royal Society of Literature'),
#  ('Lionel John Beale', 'medical'),
#  ('Frank Carr Beard', 'ESL'),
#  ('Frank Carr Beard', 'London'),
#  ('Frank Carr Beard', 'medical'),
#  ('Amos Beardsley', 'ASL'),
#  ('Amos Beardsley', 'Geological Society'),
#  ('Amos Beardsley', 'Linnean Society of London'),
#  ('Amos Beardsley', 'country'),
#  ('William Beattie', 'Biblical Archaeological Society'),
#  ('William Beattie', 'British Archaeological Society'),
#  ('William Beattie', 'ESL'),
#  ('William Beattie', 'Historical Institute'),
#  ('William Beattie', "Institut d'Afrique a Paris"),
#  ('William Beattie', 'London'),
#  ('William Beattie', 'Royal College of Physicians'),
#  ('William Beattie', 'medical'),
#  ('Richard Beaumont', 'ESL'),
#  ('Richard Beaumont', 'Royal Society'),
#  ('Richard Beaumont', 'country'),
#  ('Hugh J C Beavan', 'ASL'),
#  ('Hugh J C Beavan', 'Cannibal Club'),
#  ('Hugh J C Beavan', 'Grafton Club'),
#  ('Hugh J C Beavan', 'Junior Carlton Club'),
#  ('Hugh J C Beavan', 'London'),
#  ('Hugh J C Beavan', 'Royal Geographical Society'),
#  ('R C Beavan', 'ASL'),
#  ('R C Beavan', 'India'),
#  ('R C Beavan', 'armed services'),
#  ('Alfred Becquet', 'ASL'),
#  ('Alfred Becquet', 'Belgium'),
#  ('x Beechey', 'ESL'),
#  ('x Beechey', 'London'),
#  ('x Beechey', 'Royal Society'),
#  ('x Beechey', 'armed services'),
#  ('Hermann Beigel', 'AI'),
#  ('Hermann Beigel', 'ASL'),
#  ('Hermann Beigel', 'Austria'),
#  ('Hermann Beigel', 'Imperial Academy of Dresden'),
#  ('Hermann Beigel', 'London'),
#  ('Hermann Beigel', 'Royal College of Physicians'),
#  ('Hermann Beigel', 'medical'),
#  ('C W  Bowdler Bell', 'ASL'),
#  ('C W  Bowdler Bell', 'India'),
#  ('C W  Bowdler Bell', 'armed services'),
#  ('James Bell', 'APS'),
#  ('James Bell', 'ESL'),
#  ('James Bell', 'London'),
#  ('James Bell', 'Quaker'),
#  ('James Bell', 'Royal Institute of British Architects'),
#  ('James Bell', 'political'),
#  ('John Bell (2)', 'APS'),
#  ('John Bell (2)', 'ESL'),
#  ('John Bell (2)', 'London'),
#  ('John Bell (2)',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('John Bell (2)', 'artist'),
#  ('Robert Bell', 'APS'),
#  ('Robert Bell', 'ESL'),
#  ('William Abraham Bell', 'AI'),
#  ('William Abraham Bell', 'ESL'),
#  ('William Abraham Bell', 'London'),
#  ('William Abraham Bell', 'New University Club'),
#  ('William Abraham Bell', 'business'),
#  ('William Abraham Bell', 'medical'),
#  ('William Abraham Bell', 'photographer'),
#  ('Edward Bellamy', 'AI'),
#  ('Edward Bellamy', 'ASL'),
#  ('Edward Bellamy', 'Cannibal Club'),
#  ('Edward Bellamy', 'London'),
#  ('Edward Bellamy', 'Nationalist Club'),
#  ('Edward Bellamy', 'Royal Geographical Society'),
#  ('Edward Bellamy', 'literary'),
#  ('Henry Walter Bellew', 'AI'),
#  ('Henry Walter Bellew', 'ASL'),
#  ('Henry Walter Bellew', 'Athenaeum Club'),
#  ('Henry Walter Bellew', 'India'),
#  ('Henry Walter Bellew', 'Royal College of Surgeons'),
#  ('Henry Walter Bellew', 'armed services'),
#  ('Henry Walter Bellew', 'medical'),
#  ('William Painter Belliss', 'ASL'),
#  ('William Painter Belliss', 'London'),
#  ('William Painter Belliss', 'business'),
#  ('D Bellock', 'ASL'),
#  ('Lewis F Bellot', 'ESL'),
#  ('Adolph Bendir', 'ASL'),
#  ('Adolph Bendir', 'London'),
#  ('Adolph Bendir', 'business'),
#  ('Thomas Bendyshe', 'AI'),
#  ('Thomas Bendyshe', 'ASL'),
#  ('Thomas Bendyshe', 'Cannibal Club'),
#  ('Thomas Bendyshe', 'London'),
#  ('Thomas Bendyshe', 'academic'),
#  ('Thomas Bendyshe', 'country'),
#  ('Charles Bennett', 'AI'),
#  ('Charles Bennett', 'APS'),
#  ('Charles Bennett', 'ASL'),
#  ('Charles Bennett', 'London'),
#  ('Charles Bennett', 'Thatched House Club'),
#  ('John Bennett', 'ASL'),
#  ('John Bennett', 'Athenaeum Club'),
#  ('John Bennett', 'London'),
#  ('John Bennett', 'Royal Asiatic Society'),
#  ('John Bennett', 'business'),
#  ('Thomas John Wesley Bennett', 'ASL'),
#  ('Thomas John Wesley Bennett', 'London'),
#  ('W F G Benson', 'ASL'),
#  ('W F G Benson', 'chemist'),
#  ('W F G Benson', 'country'),
#  ('William Ralph Benson', 'ASL'),
#  ('William Ralph Benson', 'India'),
#  ('William Ralph Benson', 'legal'),
#  ('Richard Bentley', 'ESL'),
#  ('Richard Bentley', 'business'),
#  ('Bartholomew Bernasconi', 'ESL'),
#  ('Bartholomew Bernasconi', 'London'),
#  ('Bartholomew Bernasconi', 'country'),
#  ('George Bertram', 'AI'),
#  ('George Bertram', 'ASL'),
#  ('George Bertram', 'Scotland'),
#  ('George Bertram', 'business'),
#  ('Camille Bertrand', 'ASL'),
#  ('Camille Bertrand', 'France'),
#  ('Camille Bertrand', 'medical'),
#  ('x Best', 'ASL'),
#  ('x Best',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('x Best', 'armed services'),
#  ('x Best', 'country'),
#  ('John Henry Biddles', 'ASL'),
#  ('John Henry Biddles', 'London'),
#  ('John Henry Biddles', 'legal'),
#  ('Thomas Bigg', 'ESL'),
#  ('John Bilderbeck', 'AI'),
#  ('John Bilderbeck', 'ASL'),
#  ('John Bilderbeck', 'India'),
#  ('John Bilderbeck', 'Royal College of Surgeons'),
#  ('John Bilderbeck', 'medical'),
#  ('Theodor Bilharz', 'ASL'),
#  ('Theodor Bilharz', 'Egypt'),
#  ('Theodor Bilharz', 'medical'),
#  ('Henry Corles Bingham', 'ASL'),
#  ('Henry Corles Bingham', 'country'),
#  ('James Bird', 'APS'),
#  ('R S Birkbeck', 'ESL'),
#  ('James Bischoff', 'AI'),
#  ('James Bischoff', 'ASL'),
#  ('James Bischoff', 'London'),
#  ('James Bischoff',
#   'Royal Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('James Bischoff', 'Zoological Society'),
#  ('Andrew Black', 'AI'),
#  ('Andrew Black', 'ASL'),
#  ('Andrew Black', 'Glasgow Art Club'),
#  ('Andrew Black', 'Royal Scottish Society of Painters in Water Colours'),
#  ('Andrew Black', 'Scotland'),
#  ('Andrew Black', 'artist'),
#  ('W H Black', 'ESL'),
#  ('William Blackmore', 'AI'),
#  ('William Blackmore', 'ESL'),
#  ('William Blackmore', 'London'),
#  ('William Blackmore', 'country'),
#  ('William Blackmore', 'legal'),
#  ('William Blackmore', 'museum work'),
#  ('Alan Cornwall Blackstone', 'ASL'),
#  ('Alan Cornwall Blackstone', 'London'),
#  ('Alan Cornwall Blackstone', 'Royal Geographical Society'),
#  ('J H Blackwell', 'ESL'),
#  ('T A Blakely', 'ASL'),
#  ('T A Blakely', 'Army & Navy Club'),
#  ('T A Blakely', 'British Association'),
#  ('T A Blakely', 'London'),
#  ('T A Blakely', 'Royal Irish Academy'),
#  ('T A Blakely', 'Royal Society'),
#  ('T A Blakely', 'Royal United Service Institution'),
#  ('T A Blakely', 'Royal Victoria Yacht Club'),
#  ('T A Blakely', 'Society of Engineers'),
#  ('T A Blakely', 'armed services'),
#  ('Henry Jules Blanc', 'AI'),
#  ('Henry Jules Blanc', 'ASL'),
#  ('Henry Jules Blanc', 'ESL'),
#  ('Henry Jules Blanc', 'France'),
#  ('Henry Jules Blanc', 'London'),
#  ('Henry Jules Blanc', 'Royal College of Surgeons Edinburgh'),
#  ('Henry Jules Blanc', 'medical'),
#  ('Sydney L Blanchard', 'ASL'),
#  ('Sydney L Blanchard', 'Arundel Club'),
#  ('Sydney L Blanchard', 'London'),
#  ('Albert Taylor Bledsoe', 'ASL'),
#  ('Albert Taylor Bledsoe', 'America'),
#  ('Albert Taylor Bledsoe', 'London'),
#  ('Albert Taylor Bledsoe', 'legal'),
#  ('David Blellock', 'ASL'),
#  ('David Blellock', 'London'),
#  ('David Blellock', 'legal'),
#  ('John Hillier Blount', 'ASL'),
#  ('John Hillier Blount', 'India'),
#  ('John Hillier Blount', 'country'),
#  ('John Hillier Blount', 'medical'),
#  ('Frederick Edmund Blyth', 'ASL'),
#  ('Frederick Edmund Blyth', 'London'),
#  ('Henry S Boase', 'ASL'),
#  ('Henry S Boase', 'Geological Society'),
#  ('Henry S Boase', 'Royal Society'),
#  ('Henry S Boase', 'Scotland'),
#  ('Henry S Boase', 'medical'),
#  ('Anatoly Petrovich Bogdanoff', 'ASL'),
#  ('Anatoly Petrovich Bogdanoff', 'Anthropological Society of Moscow'),
#  ('Anatoly Petrovich Bogdanoff', 'Russia'),
#  ('Anatoly Petrovich Bogdanoff', 'academic'),
#  ('Edward B Bogg', 'ASL'),
#  ('Edward B Bogg', 'Canada'),
#  ('Edward B Bogg', 'armed services'),
#  ('Edward B Bogg', 'medical'),
#  ('Henry George Bohn', 'AI'),
#  ('Henry George Bohn', 'ESL'),
#  ('Henry George Bohn', 'Linnean Society of London'),
#  ('Henry George Bohn', 'London'),
#  ('Henry George Bohn', 'Royal Astronomical Society'),
#  ('Henry George Bohn', 'Royal Geographical Society'),
#  ('Henry George Bohn', 'Royal Society of Literature'),
#  ('Henry George Bohn', 'publisher'),
#  ('John Peter Boileau', 'ESL'),
#  ('John Peter Boileau', 'London'),
#  ('John Peter Boileau', 'aristocracy'),
#  ('Henry James Bolding', 'Australia'),
#  ('Henry James Bolding', 'ESL'),
#  ('Charles W Bollaert', 'ASL'),
#  ('Charles W Bollaert', 'Argentina'),
#  ('William Bollaert', 'AI'),
#  ('William Bollaert', 'ASL'),
#  ('William Bollaert', 'ESL'),
#  ('William Bollaert', 'Ethnological Society, New York'),
#  ('William Bollaert', 'London'),
#  ('William Bollaert', 'Royal Geographical Society'),
#  ('William Bollaert', 'chemist'),
#  ('William Bollaert', 'ethnologist'),
#  ('William Bollaert', 'geographer'),
#  ('William Bollaert', 'literary'),
#  ('Louis Lucien Bonaparte', 'AI'),
#  ('Louis Lucien Bonaparte', 'Athenaeum Club'),
#  ('Louis Lucien Bonaparte', 'ESL'),
#  ('Louis Lucien Bonaparte', 'France'),
#  ('Louis Lucien Bonaparte', 'London'),
#  ('Louis Lucien Bonaparte', 'academic'),
#  ('Louis Lucien Bonaparte', 'aristocracy'),
#  ('Louis Lucien Bonaparte', 'political'),
#  ('E Bonavia', 'ESL'),
#  ('E Bonavia', 'London'),
#  ('E Bonavia', 'medical'),
#  ('E Bonavia', 'museum work'),
#  ('George Bonavia', 'AI'),
#  ('George Bonavia', 'ESL'),
#  ('George Bonavia', 'London'),
#  ('George Bonavia', 'artist'),
#  ('Charles Radcliffe Bond', 'ASL'),
#  ('Charles Radcliffe Bond', 'London'),
#  ('Charles Radcliffe Bond', 'Royal College of Surgeons'),
#  ('Charles Radcliffe Bond', 'medical'),
#  ('Walter M Bond', 'ASL'),
#  ('Walter M Bond', 'Ireland'),
#  ('George Bonham', 'Athenaeum Club'),
#  ('George Bonham', 'ESL'),
#  ('George Bonham', 'London'),
#  ('George Bonham', 'administrative'),
#  ('George Bonham', 'aristocracy'),
#  ('W C Bonnerjee', 'ASL'),
#  ('W C Bonnerjee', 'Geological Society'),
#  ('W C Bonnerjee', 'London'),
#  ('W C Bonnerjee', 'legal'),
#  ('T  George Bonney', 'ASL'),
#  ('T  George Bonney', 'Athenaeum Club'),
#  ('T  George Bonney', 'Geological Society'),
#  ('T  George Bonney', 'Royal Society'),
#  ('T  George Bonney', 'church'),
#  ('T  George Bonney', 'country'),
#  ('Evert Julius Bonsdorff', 'ASL'),
#  ('Evert Julius Bonsdorff', 'Finland'),
#  ('Evert Julius Bonsdorff', 'anatomist'),
#  ('Evert Julius Bonsdorff', 'medical'),
#  ('Evert Julius Bonsdorff', 'zoologist'),
#  ('James Bonsor', 'AI'),
#  ('James Bonsor', 'ASL'),
#  ('James Bonsor', 'London'),
#  ('James Bonsor',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('James Bonsor', 'business'),
#  ('James Bonwick', 'AI'),
#  ('James Bonwick', 'ASL'),
#  ('James Bonwick', 'Australia'),
#  ('James Bonwick', 'ESL'),
#  ('James Bonwick', 'London'),
#  ('James Bonwick', 'Royal Geographical Society'),
#  ('James Bonwick', 'educator'),
#  ('James Bonwick', 'literary'),
#  ('Charles Booth', 'ASL'),
#  ('Charles Booth', 'Athenaeum Club'),
#  ('Charles Booth', 'London'),
#  ('Charles Booth', 'country'),
#  ('W W Boreham', 'ASL'),
#  ('W W Boreham', 'Royal Astronomical Society'),
#  ('Cunningham Borthwick', 'AI'),
#  ('Cunningham Borthwick', 'ASL'),
#  ('Cunningham Borthwick', 'London'),
#  ('Cunningham Borthwick', 'Society of Antiquaries'),
#  ('Cunningham Borthwick', 'aristocracy'),
#  ('Cunningham Borthwick', 'political'),
#  ('Joseph Bosworth', 'ASL'),
#  ('Joseph Bosworth', 'Royal Institute of the Netherlands'),
#  ('Joseph Bosworth', 'Royal Society'),
#  ('Joseph Bosworth', 'Society of Antiquaries of Literature'),
#  ('Joseph Bosworth', 'academic'),
#  ('Joseph Bosworth', 'church'),
#  ('Joseph Bosworth', 'country'),
#  ('Beriah Botfield', 'Athenaeum Club'),
#  ('Beriah Botfield', 'British Archaeological Association'),
#  ('Beriah Botfield', 'ESL'),
#  ('Beriah Botfield', 'London'),
#  ('Beriah Botfield', 'Royal Society'),
#  ('Beriah Botfield',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('Beriah Botfield', 'Society of Antiquaries'),
#  ('Beriah Botfield', 'political'),
#  ('x Boucher de Crevecoeur de Perthes', 'ASL'),
#  ('x Boucher de Crevecoeur de Perthes', 'Anthropological Society of Paris'),
#  ('x Boucher de Crevecoeur de Perthes', 'ESL'),
#  ('x Boucher de Crevecoeur de Perthes', 'France'),
#  ('x Boucher de Crevecoeur de Perthes', 'Geological Society'),
#  ('x Boucher de Crevecoeur de Perthes', 'academic'),
#  ('x Boudin', 'ASL'),
#  ('x Boudin', 'ESL'),
#  ('x Boudin', 'France'),
#  ('x Boudin', 'medical'),
#  ('George Boulton', 'ASL'),
#  ('George Boulton', 'London'),
#  ('George Boulton',
#   'Royal Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('Brasseur de Bourbourg', 'ASL'),
#  ('Brasseur de Bourbourg', 'France'),
#  ('Brasseur de Bourbourg', 'archaeologist'),
#  ('Brasseur de Bourbourg', 'ethnographer'),
#  ('Brasseur de Bourbourg', 'historian'),
#  ('Brasseur de Bourbourg', 'literary'),
#  ('x Bourien', 'ESL'),
#  ('x Bourien', 'church'),
#  ('Philip Bourjeaurd', 'ESL'),
#  ('Philip Bourjeaurd', 'London'),
#  ('Philip Bourjeaurd', 'inventor'),
#  ('Philip Bourjeaurd', 'medical'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'AI'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'ASL'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'Athenaeum Club'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'ESL'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'Folklore Society'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'London'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'Royal Geographical Society'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'country'),
#  ('Sydney Edward Bouverie Bouverie-Pusey', 'literary'),
#  ('Frederick Bower', 'ESL'),
#  ('Robert Bowie', 'ESL'),
#  ('Thomas William Bowman', 'ASL'),
#  ('Thomas William Bowman', 'Royal Society of Literature'),
#  ('Thomas William Bowman', 'academic'),
#  ('Thomas William Bowman', 'country'),
#  ('John Bowring', 'Athenaeum Club'),
#  ('John Bowring', 'ESL'),
#  ('John Bowring',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('John Bowring', 'administrative'),
#  ('John Bowring', 'country'),
#  ('John Bowring', 'political'),
#  ('William Henry Wentworth Bowyer', 'ASL'),
#  ('William Henry Wentworth Bowyer', 'London'),
#  ('William Henry Wentworth Bowyer', 'church'),
#  ('William Boxall', 'Athenaeum Club'),
#  ('William Boxall', 'ESL'),
#  ('William Boxall', 'artist'),
#  ('William Boxall', 'museum work'),
#  ('William Binnington Boyce', 'ASL'),
#  ('William Binnington Boyce', 'London'),
#  ('William Binnington Boyce', 'Royal Geographical Society'),
#  ('William Binnington Boyce', 'Weslyan Mission Society'),
#  ('William Binnington Boyce', 'church'),
#  ('Jacob Boys', 'AI'),
#  ('Jacob Boys', 'ASL'),
#  ('Jacob Boys', 'country'),
#  ('Jacob Boys', 'legal'),
#  ('Edward William Brabrook', 'AI'),
#  ('Edward William Brabrook', 'ASL'),
#  ('Edward William Brabrook', 'Anthropological Society of Paris'),
#  ('Edward William Brabrook', 'Athenaeum Club'),
#  ('Edward William Brabrook', 'Colquehoun Club'),
#  ('Edward William Brabrook', 'Folklore Society'),
#  ('Edward William Brabrook', 'London'),
#  ('Edward William Brabrook',
#   'London and Middlesex Archaeological Association'),
#  ('Edward William Brabrook', 'Royal Society of Literature'),
#  ('Edward William Brabrook',
#   'Royal Society of Northern Antiquities Copenhagen'),
#  ('Edward William Brabrook', 'Society of Antiquaries'),
#  ('Edward William Brabrook', 'Statistical Society'),
#  ('Edward William Brabrook', 'civil service'),
#  ('Edward William Brabrook', 'legal'),
#  ('Frederick Braby', 'AI'),
#  ('Frederick Braby', 'ASL'),
#  ('Frederick Braby', 'Chemical Society'),
#  ('Frederick Braby', 'Geological Society'),
#  ('Frederick Braby', 'London'),
#  ('Frederick Braby',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('Frederick Braby', 'ironmaker'),
#  ('Charles Holt Bracebridge', 'AI'),
#  ('Charles Holt Bracebridge', 'Athenaeum Club'),
#  ('Charles Holt Bracebridge', 'ESL'),
#  ('Charles Holt Bracebridge', 'London'),
#  ('Charles Holt Bracebridge', 'literary'),
#  ('Thomas Braddell', 'ESL'),
#  ('Thomas Braddell', 'Singapore'),
#  ('Thomas Braddell', 'administrative'),
#  ('Thomas Braddell', 'legal'),
#  ('Antonio Brady', 'AI'),
#  ('Antonio Brady', 'APS'),
#  ('Antonio Brady', 'ASL'),
#  ('Antonio Brady', 'Geological Society'),
#  ('Antonio Brady', 'Quaker'),
#  ('Antonio Brady',
#   'Society for the Encouragement of Arts, Manufactures and Commerce'),
#  ('Antonio Brady', 'academic'),
#  ('Antonio Brady', 'armed services'),
#  ('Antonio Brady', 'country'),
#  ('James Brady', 'ESL'),
#  ('P A Brady', 'AI'),
#  ('P A Brady', 'ASL'),
#  ('P A Brady', 'country'),
#  ('P A Brady', 'medical'),
#  ('William Bragge', 'AI'),
#  ('William Bragge', 'ESL'),
#  ('William Bragge', 'Geological Society'),
#  ('William Bragge', 'Royal Geographical Society'),
#  ('William Bragge', 'Society of Antiquaries'),
#  ('William Bragge', 'business'),
#  ('William Bragge', 'civil engineer'),
#  ('William Bragge', 'country'),
#  ('William Bragge', 'museum work'),
#  ('George M Braggiotti', 'ASL'),
#  ('George M Braggiotti', 'America'),
#  ('Thomas Henry Brain', 'ESL'),
#  ('Thomas Henry Brain', 'church'),
#  ('Charles Brainsford', 'ASL'),
#  ('Charles Brainsford', 'country'),
#  ('Charles Brainsford', 'medical'),
#  ('Thomas Brankstone', 'ASL'),
#  ('Thomas Brankstone', 'London'),
#  ('Frank William Breach', 'ASL'),
#  ('Frank William Breach', 'Mexico'),
#  ('Frank William Breach', 'business'),
#  ('A C Brebner', 'AI'),
#  ('A C Brebner', 'ASL'),
#  ('A C Brebner', 'London'),
#  ('A C Brebner', 'civil service'),
#  ('James Brebner', 'AI'),
#  ('James Brebner', 'ASL'),
#  ('James Brebner', 'Aberdeen Horticultural Society'),
#  ('James Brebner', 'Scotland'),
#  ('James Brebner', 'Spalding Club'),
#  ('James Brebner', 'legal'),
#  ('William Brent Brent', 'ESL'),
#  ('William Brent Brent', 'France'),
#  ('William Brent Brent', 'London'),
#  ('Charles Brett', 'AI'),
#  ('Charles Brett', 'ASL'),
#  ('Charles Brett', 'London'),
#  ('Charles Brett', 'Royal Geographical Society'),
#  ('D J Breuneis', 'ESL'),
#  ('D J Breuneis', 'London'),
#  ('J S Brickwood', 'ASL'),
#  ('J S Brickwood', 'country'),
#  ('Edmund J Bridell', 'ESL'),
#  ('John Briggs', 'AI'),
#  ('John Briggs', 'Athenaeum Club'),
#  ('John Briggs', 'ESL'),
#  ('John Briggs', 'London'),
#  ('John Briggs', 'Oriental Club'),
#  ('John Briggs', 'armed services'),
#  ('John Briggs', 'literary'),
#  ('Lindsay Brine', 'AI'),
#  ('Lindsay Brine', 'Army & Navy Club'),
#  ('Lindsay Brine', 'Athenaeum Club'),
#  ('Lindsay Brine', 'ESL'),
#  ('Lindsay Brine', 'London'),
#  ('Lindsay Brine', 'Royal Geographical Society'),
#  ('Lindsay Brine', 'armed services'),
#  ('John Brinton', 'ASL'),
#  ('John Brinton', 'business'),
#  ('John Brinton', 'country'),
#  ('John Brinton', 'political'),
#  ('Bernard Edward Brodhurst', 'ASL'),
#  ('Bernard Edward Brodhurst', 'Athenaeum Club'),
#  ('Bernard Edward Brodhurst', 'London'),
#  ('Bernard Edward Brodhurst', 'Royal College of Surgeons'),
#  ('Bernard Edward Brodhurst', 'medical'),
#  ('Benjamin Collins Brodie', 'Athenaeum Club'),
#  ('Benjamin Collins Brodie', 'Chemical Society'),
#  ('Benjamin Collins Brodie', 'ESL'),
#  ('Benjamin Collins Brodie', 'aristocracy'),
#  ('Benjamin Collins Brodie', 'medical'),
#  ('David Brodie', 'ASL'),
#  ('David Brodie', 'Royal College of Surgeons Edinburgh'),
#  ('David Brodie', 'Scotland'),
#  ('David Brodie', 'medical'),
#  ('P B Brodie', 'ASL'),
#  ('P B Brodie', 'Geological Society'),
#  ('P B Brodie', 'Linnean Society of London'),
#  ('P B Brodie', 'Woolhope Naturalists Field Club'),
#  ('P B Brodie', 'church'),
#  ('P B Brodie', 'country'),
#  ('Frederick Brome', 'ASL'),
#  ('Frederick Brome', 'Gibraltar'),
#  ('Frederick Brome', 'armed services'),
#  ('James Brooke', 'ASL'),
#  ('James Brooke', 'Athenaeum Club'),
#  ('James Brooke', 'Ruler'),
#  ('James Brooke', 'country'),
#  ('Henry (1) Brookes', 'ESL'),
#  ('Henry (1) Brookes', 'London'),
#  ('Henry (1) Brookes', 'political'),
#  ('Henry (2) Brookes', 'ASL'),
#  ('Henry (2) Brookes', 'London'),
#  ('William Brookes', 'ASL'),
#  ('William Brookes', 'Australia'),
#  ('x Brougham', 'ESL'),
#  ('x Brougham', 'London'),
#  ('x Brougham', 'Royal Society'),
#  ('x Brougham', 'Society for the Diffusion of Useful Knowledge'),
#  ('x Brougham', 'aristocracy'),
#  ('x Brougham', 'political'),
#  ('Charles Cornish Brown', 'AI'),
#  ('Charles Cornish Brown', 'ASL'),
#  ('Charles Cornish Brown', 'Royal College of Surgeons'),
#  ('Charles Cornish Brown', 'country'),
#  ('Charles Cornish Brown', 'medical'),
#  ('Edward Brown', 'ASL'),
#  ('Edward Brown', 'London'),
#  ('Edwin Brown', 'ASL'),
#  ('Edwin Brown', 'Botanical Society of London'),
#  ('Edwin Brown', 'Entomological Society of London'),
#  ('Edwin Brown', 'Geological Society'),
#  ('Edwin Brown', 'Midland Natural History Society'),
#  ('Edwin Brown', 'Royal Geographical Society'),
#  ('Edwin Brown', 'business'),
#  ('Edwin Brown', 'country'),
#  ('Edwin Ormond Brown', 'ASL'),
#  ('Edwin Ormond Brown', 'Chemical Society'),
#  ('Edwin Ormond Brown', 'London'),
#  ('George W  (1) Brown', 'ASL'),
#  ('George W  (1) Brown', 'Australia'),
#  ('George W  (1) Brown', 'business'),
#  ('James Roberts Brown', 'AI'),
#  ...]

# %%
print(len(node_names))
print(len(edges))
# Out:
# 3560
# 9992

# %%
G = nx.Graph()
G.add_nodes_from(node_names)
G.add_edges_from(edges)
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 3560
# Number of edges: 9992
# Average degree:   5.6135

# %%
nx.write_gexf(G, 'jnb_hddt_intro.gexf')

# %% [markdown]
# # This is BIG data! #
#
# <img src="intro.png">

# %% [markdown]
# # END #
